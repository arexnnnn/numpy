# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("apple.jpeg")
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=676x473>

# %%
arr = np.array(pil)
arr.shape
# Out:
# (473, 676, 3)

# %%
cut = arr[:5, :5]
plt.imshow(cut)

# %%
rgb = Image.open("rgb.png")
rgb
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=275x183>

# %%
red = arr[:, :, 2]
plt.imshow(red)

# %%
gray = arr.mean(axis=2)
plt.imshow(gray, cmap("gray"))
